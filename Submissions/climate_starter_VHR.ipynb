# %%
# Personal Prefered Dependencies

# Default styke guide
from matplotlib import style
style.use('fivethirtyeight')

# Data Analysis and Manipukation
import numpy as np
import pandas as pd
import datetime as dt

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st

# Python SQL toolkit and Object Relational Mapper Stuff
from sqlalchemy import create_engine, inspect, text, func # func added
from sqlalchemy.orm import Session
from sqlalchemy.ext.automap import automap_base

# import sqlalchemy Not needed per instructor

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM
#
# Instructor prefered to use SQL over ORM and alllowed/ encouraged us to use SQL for this assingment

# %%
# Create engine using the `hawaii.sqlite` database file
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# Reference code from 10/2/8
# Create the inspector and connect it to the engine
inspector = inspect(engine)

# Collect the names of tables within the database
tables = inspector.get_table_names()

# Using the inspector to print the column names within the 'dow' table and its types
for table in tables:
    print(table)
    print("--------")
    columns = inspector.get_columns(table)
    for column in columns:
        print(column["name"], column["type"])

    print()
# Out:
# measurement
# --------
# id INTEGER
# station TEXT
# date TEXT
# prcp FLOAT
# tobs FLOAT
#
# station
# --------
# id INTEGER
# station TEXT
# name TEXT
# latitude FLOAT
# longitude FLOAT
# elevation FLOAT

# %%
# Reference code From 10/2/8
# Declare a Base using `automap_base()`
Base = automap_base()

# Use the Base class to reflect the database tables
Base.prepare(autoload_with=engine)

# Print all of the classes mapped to the Base
Base.classes.keys()
# Out:
# ['station', 'measurement']

# %%
# Assign the measurement class to a variable called `Measurement` and
# the station class to a variable called `Station`
Station = Base.classes.station
Measurement = Base.classes.measurement

# %%
# Create a session/Open the threads
session = Session(engine) # ORM
conn = engine.connect() # Raw SQL Pandas

# %%
# Data Review
query = text("""SELECT * from station LIMIT 10""")
df_station = pd.read_sql(query, con=conn)
df_station
# Out:
#    id      station                                    name  latitude  \
# 0   1  USC00519397                    WAIKIKI 717.2, HI US  21.27160
# 1   2  USC00513117                    KANEOHE 838.1, HI US  21.42340
# 2   3  USC00514830  KUALOA RANCH HEADQUARTERS 886.9, HI US  21.52130
# 3   4  USC00517948                       PEARL CITY, HI US  21.39340
# 4   5  USC00518838              UPPER WAHIAWA 874.3, HI US  21.49920
# 5   6  USC00519523      WAIMANALO EXPERIMENTAL FARM, HI US  21.33556
# 6   7  USC00519281                     WAIHEE 837.5, HI US  21.45167
# 7   8  USC00511918       HONOLULU OBSERVATORY 702.2, HI US  21.31520
# 8   9  USC00516128            MANOA LYON ARBO 785.2, HI US  21.33310
#
#    longitude  elevation
# 0 -157.81680        3.0
# 1 -157.80150       14.6
# 2 -157.83740        7.0
# 3 -157.97510       11.9
# 4 -158.01110      306.6
# 5 -157.71139       19.5
# 6 -157.84889       32.9
# 7 -157.99920        0.9
# 8 -157.80250      152.4

# %%
# Data Review
query = text("""SELECT * from measurement LIMIT 10""")
df_measurement = pd.read_sql(query, con=conn)
df_measurement
# Out:
#    id      station        date  prcp  tobs
# 0   1  USC00519397  2010-01-01  0.08  65.0
# 1   2  USC00519397  2010-01-02  0.00  63.0
# 2   3  USC00519397  2010-01-03  0.00  74.0
# 3   4  USC00519397  2010-01-04  0.00  76.0
# 4   5  USC00519397  2010-01-06   NaN  73.0
# 5   6  USC00519397  2010-01-07  0.06  70.0
# 6   7  USC00519397  2010-01-08  0.00  64.0
# 7   8  USC00519397  2010-01-09  0.00  68.0
# 8   9  USC00519397  2010-01-10  0.00  73.0
# 9  10  USC00519397  2010-01-11  0.01  64.0

# %% [markdown]
# # Exploratory Precipitation Analysis

# %%
# Find the most recent date in the data set.
query = text("""SELECT max(date) FROM measurement;""")
conn.execute(query).fetchall()

# ORM
# session.query(func.max(Measurmenent.date)).all()
# Out:
# [('2017-08-23',)]

# %%
# SQL
# Design a query to retrieve the last 12 months of precipitation data and plot the results.
# Starting from the most recent data point in the database.

# Calculate the date one year from the last date in data set.
# Perform a query to retrieve the data and precipitation scores
# Save the query results as a Pandas DataFrame. Explicitly set the column names
# Sort the dataframe by date

query = text("""SELECT
                    id,
                    station,
                    date,
                    prcp
                    
                FROM
                    measurement
                WHERE
                    date >= '2016-08-23'
                ORDER BY
                    date;""")
df_date = pd.read_sql(query, con=conn)
df_date.columns = ['id', 'station', 'date', 'prcp']
# df_date.head()
df_date
# Out:
#          id      station        date  prcp
# 0      2364  USC00519397  2016-08-23  0.00
# 1      5091  USC00513117  2016-08-23  0.15
# 2      7331  USC00514830  2016-08-23  0.05
# 3      8825  USC00517948  2016-08-23   NaN
# 4     11851  USC00519523  2016-08-23  0.02
# ...     ...          ...         ...   ...
# 2225  19549  USC00516128  2017-08-22  0.50
# 2226   2724  USC00519397  2017-08-23  0.00
# 2227   7635  USC00514830  2017-08-23  0.00
# 2228  12187  USC00519523  2017-08-23  0.08
# 2229  19550  USC00516128  2017-08-23  0.45
#
# [2230 rows x 4 columns]

# %%
# ORM
rows = session.query(Measurement.id, Measurement.station, Measurement.date, Measurement.prcp).filter(Measurement.date >= '2016-08-23').order_by(Measurement.date).all()
df_orm = pd.DataFrame(rows)
df_orm.head()
# Out:
#       id      station        date  prcp
# 0   2364  USC00519397  2016-08-23  0.00
# 1   5091  USC00513117  2016-08-23  0.15
# 2   7331  USC00514830  2016-08-23  0.05
# 3   8825  USC00517948  2016-08-23   NaN
# 4  11851  USC00519523  2016-08-23  0.02

# %%
# Use Pandas Plotting with Matplotlib to plot the data

plt.figure(figsize=(10, 15))
df_date.plot(x="date", y="prcp")
plt.title("Hawaii Precipitation Analysis")
plt.ylabel("Precipitation (in)")
plt.xticks(rotation=90)  # Rotate ticks by 90 degrees
plt.show()

# %%
# Use Pandas to calculate the summary statistics for the precipitation data
df_date.prcp.describe()
# Out:
# count    2021.000000
# mean        0.177279
# std         0.461190
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000
# Name: prcp, dtype: float64

# %%
# Display as Data Frame
df_stats = df_date.prcp.describe()
df = df_stats.reset_index()
df.columns = ['Statistic', 'Value']
df
# Out:
#   Statistic        Value
# 0     count  2021.000000
# 1      mean     0.177279
# 2       std     0.461190
# 3       min     0.000000
# 4       25%     0.000000
# 5       50%     0.020000
# 6       75%     0.130000
# 7       max     6.700000

# %% [markdown]
# # Exploratory Station Analysis

# %%
# Design a query to calculate the total number of stations in the dataset
# Find the most recent date in the data set.
query = text("""SELECT count(station) FROM station;""")
conn.execute(query).fetchall()
# Out:
# [(9,)]

# %%
# ORM
session.query(func.count(Station.station)).all()
# Out:
# [(9,)]

# %%
# SQL
# Design a query to find the most active stations (i.e. which stations have the most rows?)
# List the stations and their counts in descending order.

query = text("""SELECT
                    station,
                    count(id) as num_observations
                FROM
                    measurement
                GROUP BY
                    station
                ORDER by 
                    num_observations desc;""")
df_station = pd.read_sql(query, con=conn)
df_station
# Out:
#        station  num_observations
# 0  USC00519281              2772
# 1  USC00519397              2724
# 2  USC00513117              2709
# 3  USC00519523              2669
# 4  USC00516128              2612
# 5  USC00514830              2202
# 6  USC00511918              1979
# 7  USC00517948              1372
# 8  USC00518838               511

# %%
# ORM 
results = session.query( Measurement.station, func.count(Measurement.id).label('count') 
                       ).group_by(Measurement.station).order_by(func.count(Measurement.id).desc()).all() 

df_orm = pd.read_sql(query, con=conn)
df_orm
# Out:
#        station  num_observations
# 0  USC00519281              2772
# 1  USC00519397              2724
# 2  USC00513117              2709
# 3  USC00519523              2669
# 4  USC00516128              2612
# 5  USC00514830              2202
# 6  USC00511918              1979
# 7  USC00517948              1372
# 8  USC00518838               511

# %%
# SQL
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.
query = text("""
                SELECT 
                    MIN(tobs) AS lowest_tobs,
                    MAX(tobs) AS highest_tobs,
                    AVG(tobs) AS average_tobs
                FROM 
                    measurement
                WHERE 
                    station = 'USC00519281';""")
conn.execute(query).fetchall()
# Out:
# [(54.0, 85.0, 71.66378066378067)]

# %%
# Convert into Data frame
df_tobs = pd.read_sql(query, con=conn)
df_tobs
# Out:
#    lowest_tobs  highest_tobs  average_tobs
# 0         54.0          85.0     71.663781

# %%
# ORM
# Using the most active station id from the previous query, calculate the lowest, highest, and average temperature.
results = session.query( func.min(Measurement.tobs).label('lowest_tobs'), func.max(Measurement.tobs).label('highest_tobs'), func.avg(Measurement.tobs).label('average_tobs') 
).filter(Measurement.station == 'USC00519281').one()
df_orm1 = pd.read_sql(query, con=conn)
df_orm1
# Out:
#    lowest_tobs  highest_tobs  average_tobs
# 0         54.0          85.0     71.663781

# %%
# Using the most active station id
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
# SQL
query = text("""SELECT
                    id,
                    station,
                    date,
                    tobs    
                FROM
                    measurement
                WHERE
                    station = 'USC00519281'
                    and date >= '2016-08-23'
                ORDER BY
                    date;""")
df_tobs1 = pd.read_sql(query, con=conn)
# df_date.columns = ['id', 'station', 'date', 'prcp']
# df_date.head()
df_tobs1
# Out:
#         id      station        date  tobs
# 0    14608  USC00519281  2016-08-23  77.0
# 1    14609  USC00519281  2016-08-24  77.0
# 2    14610  USC00519281  2016-08-25  80.0
# 3    14611  USC00519281  2016-08-26  80.0
# 4    14612  USC00519281  2016-08-27  75.0
# ..     ...          ...         ...   ...
# 347  14955  USC00519281  2017-08-14  77.0
# 348  14956  USC00519281  2017-08-15  77.0
# 349  14957  USC00519281  2017-08-16  76.0
# 350  14958  USC00519281  2017-08-17  76.0
# 351  14959  USC00519281  2017-08-18  79.0
#
# [352 rows x 4 columns]

# %%
# ORM
# Using the most active station id
# Query the last 12 months of temperature observation data for this station
rows = session.query(Measurement.id, Measurement.station, Measurement.date, Measurement.tobs).filter(Measurement.station == 'USC00519281', Measurement.date >= '2016-08-23').order_by(Measurement.date).all()
df_orm1 = pd.DataFrame(rows)
df_orm1
# Out:
#         id      station        date  tobs
# 0    14608  USC00519281  2016-08-23  77.0
# 1    14609  USC00519281  2016-08-24  77.0
# 2    14610  USC00519281  2016-08-25  80.0
# 3    14611  USC00519281  2016-08-26  80.0
# 4    14612  USC00519281  2016-08-27  75.0
# ..     ...          ...         ...   ...
# 347  14955  USC00519281  2017-08-14  77.0
# 348  14956  USC00519281  2017-08-15  77.0
# 349  14957  USC00519281  2017-08-16  76.0
# 350  14958  USC00519281  2017-08-17  76.0
# 351  14959  USC00519281  2017-08-18  79.0
#
# [352 rows x 4 columns]

# %%
# Plot the results as a histogram
# Create a histogram plot 

df_tobs1['tobs'].plot(kind='hist', bins=12) 
# Add titles and labels 
plt.title('Hawaii Temperature Observation\nfor Station USC00519281')
plt.xlabel('Temperature (F)') 
plt.ylabel('Frequency')
# Show the plot plt.show()
plt.show()

# %% [markdown]
# # Close Session

# %%
# Close Session
session.close()
